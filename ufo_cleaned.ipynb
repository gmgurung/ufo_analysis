# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ufo_sightings_scrubbed.csv')
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_52204\383649762.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ufo_sightings_scrubbed.csv')

# %%
df
# Out:
#                   datetime                  city state country     shape  \
# 0      1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1      1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2      1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3      1956-10-10 21:00:00                  edna    tx      us    circle
# 4      1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                    ...                   ...   ...     ...       ...
# 80327  2013-09-09 21:15:00             nashville    tn      us     light
# 80328  2013-09-09 22:00:00                 boise    id      us    circle
# 80329  2013-09-09 22:00:00                  napa    ca      us     other
# 80330  2013-09-09 22:20:00                vienna    va      us    circle
# 80331  2013-09-09 23:00:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# ...

# %%
df.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#                   datetime                  city state country     shape  \
# 0      1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1      1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2      1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3      1956-10-10 21:00:00                  edna    tx      us    circle
# 4      1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                    ...                   ...   ...     ...       ...
# 80327  2013-09-09 21:15:00             nashville    tn      us     light
# 80328  2013-09-09 22:00:00                 boise    id      us    circle
# 80329  2013-09-09 22:00:00                  napa    ca      us     other
# 80330  2013-09-09 22:20:00                vienna    va      us    circle
# 80331  2013-09-09 23:00:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# ...

# %%
pd.isna(df1)
# Out:
#        datetime   city  state  country  shape  duration (seconds)  \
# 0         False  False  False    False  False               False
# 1         False  False  False     True  False               False
# 2         False  False   True    False  False               False
# 3         False  False  False    False  False               False
# 4         False  False  False    False  False               False
# ...         ...    ...    ...      ...    ...                 ...
# 80327     False  False  False    False  False               False
# 80328     False  False  False    False  False               False
# 80329     False  False  False    False  False               False
# 80330     False  False  False    False  False               False
# 80331     False  False  False    False  False               False
#
#        duration (hours/min)  comments  date posted  latitude  longitude
# 0                     False     False        False     False       False
# ...

# %%
df1
# Out:
#                   datetime                  city state country     shape  \
# 0      1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1      1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2      1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3      1956-10-10 21:00:00                  edna    tx      us    circle
# 4      1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                    ...                   ...   ...     ...       ...
# 80327  2013-09-09 21:15:00             nashville    tn      us     light
# 80328  2013-09-09 22:00:00                 boise    id      us    circle
# 80329  2013-09-09 22:00:00                  napa    ca      us     other
# 80330  2013-09-09 22:20:00                vienna    va      us    circle
# 80331  2013-09-09 23:00:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# ...

# %%
df1.dropna(how="any",inplace=True)

# %%
df1
# Out:
#                   datetime        city state country     shape  \
# 0      1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3      1956-10-10 21:00:00        edna    tx      us    circle
# 4      1960-10-10 20:00:00     kaneohe    hi      us     light
# 5      1961-10-10 19:00:00     bristol    tn      us    sphere
# 7      1965-10-10 23:45:00     norwalk    ct      us      disk
# ...                    ...         ...   ...     ...       ...
# 80327  2013-09-09 21:15:00   nashville    tn      us     light
# 80328  2013-09-09 22:00:00       boise    id      us    circle
# 80329  2013-09-09 22:00:00        napa    ca      us     other
# 80330  2013-09-09 22:20:00      vienna    va      us    circle
# 80331  2013-09-09 23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...

# %%
df1.head(50)
# Out:
#                datetime                                     city state  \
# 0   1949-10-10 20:30:00                               san marcos    tx
# 3   1956-10-10 21:00:00                                     edna    tx
# 4   1960-10-10 20:00:00                                  kaneohe    hi
# 5   1961-10-10 19:00:00                                  bristol    tn
# 7   1965-10-10 23:45:00                                  norwalk    ct
# 8   1966-10-10 20:00:00                                pell city    al
# 9   1966-10-10 21:00:00                                 live oak    fl
# 10  1968-10-10 13:00:00                                hawthorne    ca
# 11  1968-10-10 19:00:00                                  brevard    nc
# 12  1970-10-10 16:00:00                                 bellmore    ny
# 13  1970-10-10 19:00:00                               manchester    ky
# 14  1971-10-10 21:00:00                                lexington    nc
# ...

# %%
import matplotlib as plt

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.head(50)
# Out:
#                datetime                                     city state  \
# 0   1949-10-10 20:30:00                               san marcos    tx
# 3   1956-10-10 21:00:00                                     edna    tx
# 4   1960-10-10 20:00:00                                  kaneohe    hi
# 5   1961-10-10 19:00:00                                  bristol    tn
# 7   1965-10-10 23:45:00                                  norwalk    ct
# 8   1966-10-10 20:00:00                                pell city    al
# 9   1966-10-10 21:00:00                                 live oak    fl
# 10  1968-10-10 13:00:00                                hawthorne    ca
# 11  1968-10-10 19:00:00                                  brevard    nc
# 12  1970-10-10 16:00:00                                 bellmore    ny
# 13  1970-10-10 19:00:00                               manchester    ky
# 14  1971-10-10 21:00:00                                lexington    nc
# ...

# %%
df_copy = df1.copy()

# %%
df_copy
# Out:
#                   datetime        city state country     shape  \
# 0      1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3      1956-10-10 21:00:00        edna    tx      us    circle
# 4      1960-10-10 20:00:00     kaneohe    hi      us     light
# 5      1961-10-10 19:00:00     bristol    tn      us    sphere
# 7      1965-10-10 23:45:00     norwalk    ct      us      disk
# ...                    ...         ...   ...     ...       ...
# 80327  2013-09-09 21:15:00   nashville    tn      us     light
# 80328  2013-09-09 22:00:00       boise    id      us    circle
# 80329  2013-09-09 22:00:00        napa    ca      us     other
# 80330  2013-09-09 22:20:00      vienna    va      us    circle
# 80331  2013-09-09 23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...

# %%
df1.head(50)
# Out:
#                datetime                                     city state  \
# 0   1949-10-10 20:30:00                               san marcos    tx
# 3   1956-10-10 21:00:00                                     edna    tx
# 4   1960-10-10 20:00:00                                  kaneohe    hi
# 5   1961-10-10 19:00:00                                  bristol    tn
# 7   1965-10-10 23:45:00                                  norwalk    ct
# 8   1966-10-10 20:00:00                                pell city    al
# 9   1966-10-10 21:00:00                                 live oak    fl
# 10  1968-10-10 13:00:00                                hawthorne    ca
# 11  1968-10-10 19:00:00                                  brevard    nc
# 12  1970-10-10 16:00:00                                 bellmore    ny
# 13  1970-10-10 19:00:00                               manchester    ky
# 14  1971-10-10 21:00:00                                lexington    nc
# ...

# %%
df1= df1.drop(['comments'],axis=1)

# %%
df1
# Out:
#                   datetime        city state country     shape  \
# 0      1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3      1956-10-10 21:00:00        edna    tx      us    circle
# 4      1960-10-10 20:00:00     kaneohe    hi      us     light
# 5      1961-10-10 19:00:00     bristol    tn      us    sphere
# 7      1965-10-10 23:45:00     norwalk    ct      us      disk
# ...                    ...         ...   ...     ...       ...
# 80327  2013-09-09 21:15:00   nashville    tn      us     light
# 80328  2013-09-09 22:00:00       boise    id      us    circle
# 80329  2013-09-09 22:00:00        napa    ca      us     other
# 80330  2013-09-09 22:20:00      vienna    va      us    circle
# 80331  2013-09-09 23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted    latitude  \
# 0                   2700           45 minutes  2004-04-27  29.8830556
# ...

# %%
df1.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'date posted', 'latitude', 'longitude '],
#       dtype='object')

# %%
df1["datetime"] = pd.to_datetime(df1["datetime"])

# %%
df1.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# date posted                     object
# latitude                        object
# longitude                      float64
# dtype: object

# %%
df1['date'] = df1['datetime'].dt.date
df1['time'] = df1['datetime'].dt.time

# %%
df1
# Out:
#                  datetime        city state country     shape  \
# 0     1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3     1956-10-10 21:00:00        edna    tx      us    circle
# 4     1960-10-10 20:00:00     kaneohe    hi      us     light
# 5     1961-10-10 19:00:00     bristol    tn      us    sphere
# 7     1965-10-10 23:45:00     norwalk    ct      us      disk
# ...                   ...         ...   ...     ...       ...
# 80327 2013-09-09 21:15:00   nashville    tn      us     light
# 80328 2013-09-09 22:00:00       boise    id      us    circle
# 80329 2013-09-09 22:00:00        napa    ca      us     other
# 80330 2013-09-09 22:20:00      vienna    va      us    circle
# 80331 2013-09-09 23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted    latitude  \
# 0                   2700           45 minutes  2004-04-27  29.8830556
# 3                     20             1/2 hour  2004-01-17  28.9783333
# ...

# %%
df1.drop(columns=["datetime"],inplace=True)

# %%
df1
# Out:
#              city state country     shape duration (seconds)  \
# 0      san marcos    tx      us  cylinder               2700
# 3            edna    tx      us    circle                 20
# 4         kaneohe    hi      us     light                900
# 5         bristol    tn      us    sphere                300
# 7         norwalk    ct      us      disk               1200
# ...           ...   ...     ...       ...                ...
# 80327   nashville    tn      us     light              600.0
# 80328       boise    id      us    circle             1200.0
# 80329        napa    ca      us     other             1200.0
# 80330      vienna    va      us    circle                5.0
# 80331      edmond    ok      us     cigar             1020.0
#
#       duration (hours/min) date posted    latitude  longitude         date  \
# 0               45 minutes  2004-04-27  29.8830556  -97.941111  1949-10-10
# 3                 1/2 hour  2004-01-17  28.9783333  -96.645833  1956-10-10
# ...

# %%
df1.columns
# Out:
# Index(['city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'date posted', 'latitude', 'longitude ', 'date',
#        'time'],
#       dtype='object')

# %%
df1=df1.reindex(columns=['date','time','city', 'state', 'country', 'shape', 'duration (seconds)',
       'duration (hours/min)', 'date posted', 'latitude', 'longitude '])

# %%
df["duration (hours/min)"].dtypes
# Out:
# dtype('O')

# %%
df1["latitude"]=df1["latitude"].astype(np.float64)

# %%
df1.dtypes
# Out:
# date                     object
# time                     object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# date posted              object
# latitude                float64
# longitude               float64
# dtype: object

# %%
df1[["city","state","country"]]= df1[["city","state","country"]].astype(str)

# %%
df1.dtypes
# Out:
# date                     object
# time                     object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# date posted              object
# latitude                float64
# longitude               float64
# dtype: object

# %%
df1.dtypes
# Out:
# date                     object
# time                     object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# date posted              object
# latitude                float64
# longitude               float64
# dtype: object

# %%
df1
# Out:
#              date      time        city state country     shape  \
# 0      1949-10-10  20:30:00  san marcos    tx      us  cylinder
# 3      1956-10-10  21:00:00        edna    tx      us    circle
# 4      1960-10-10  20:00:00     kaneohe    hi      us     light
# 5      1961-10-10  19:00:00     bristol    tn      us    sphere
# 7      1965-10-10  23:45:00     norwalk    ct      us      disk
# ...           ...       ...         ...   ...     ...       ...
# 80327  2013-09-09  21:15:00   nashville    tn      us     light
# 80328  2013-09-09  22:00:00       boise    id      us    circle
# 80329  2013-09-09  22:00:00        napa    ca      us     other
# 80330  2013-09-09  22:20:00      vienna    va      us    circle
# 80331  2013-09-09  23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted   latitude  \
# 0                   2700           45 minutes  2004-04-27  29.883056
# ...

# %%
df1["city"] = df1["city"].convert_dtypes(convert_string=True)

# %%
df1.dtypes
# Out:
# date                            object
# time                            object
# city                    string[python]
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# date posted                     object
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
df1[["state","country","shape"]] = df1[["state","country","shape"]].convert_dtypes(convert_string=True)

# %%
df1.dtypes
# Out:
# date                            object
# time                            object
# city                    string[python]
# state                   string[python]
# country                 string[python]
# shape                   string[python]
# duration (seconds)              object
# duration (hours/min)            object
# date posted                     object
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
df1["date"]=pd.to_datetime(df1["date"])

# %%
df1.dtypes
# Out:
# date                    datetime64[ns]
# time                            object
# city                    string[python]
# state                   string[python]
# country                 string[python]
# shape                   string[python]
# duration (seconds)              object
# duration (hours/min)            object
# date posted                     object
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
df1.dtypes
# Out:
# date                    datetime64[ns]
# time                            object
# city                    string[python]
# state                   string[python]
# country                 string[python]
# shape                   string[python]
# duration (seconds)              object
# duration (hours/min)            object
# date posted                     object
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
len_df = len(df1["duration (hours/min)"])

# %%
len_df
# Out:
# 66516

# %%
df1["duration (hours/min)"].head(50)
# Out:
# 0             45 minutes
# 3               1/2 hour
# 4             15 minutes
# 5              5 minutes
# 7             20 minutes
# 8             3  minutes
# 9        several minutes
# 10                5 min.
# 11             3 minutes
# 12               30 min.
# 13             3 minutes
# 14            30 seconds
# 15             20minutes
# 16             2 minutes
# 17             20-30 min
# 19            45 minutes
# 21             one hour?
# 22           5-6 minutes
# 23              1 minute
# 25            30 seconds
# 26    approx: 30 seconds
# 27                  5min
# 28            15 minutes
# 30             3 minutes
# 31               30mins.
# 32                 3 min
# 33             5 minutes
# 34            3 to 5 min
# 36              1 minute
# 37        couple minutes
# 38         15-20 seconds
# 41            10 minutes
# 42           few minutes
# 43              1 minute
# 44                2 sec.
# 45          approx 5 min
# 46              1 minute
# ...

# %%
len(df1["duration (hours/min)"])
# Out:
# 66516

# %%
def get_int1(data):
    int_val = []
    for item in data:
        clean_dtr = ''.join(filter(str.isdigit,item))
        if clean_dtr:
            int_val.append(int(clean_dtr))
    return int_val

# %%
get_int1(df1["duration (hours/min)"])
number = pd.Series(get_int1(df1["duration (hours/min)"]))

# %%
number
# Out:
# 0        45
# 1        12
# 2        15
# 3         5
# 4        20
#          ..
# 63570    20
# 63571    10
# 63572    20
# 63573     5
# 63574    17
# Length: 63575, dtype: int64

# %%
df1["duration"] = number

# %%
df1
# Out:
#             date      time        city state country     shape  \
# 0     1949-10-10  20:30:00  san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00        edna    tx      us    circle
# 4     1960-10-10  20:00:00     kaneohe    hi      us     light
# 5     1961-10-10  19:00:00     bristol    tn      us    sphere
# 7     1965-10-10  23:45:00     norwalk    ct      us      disk
# ...          ...       ...         ...   ...     ...       ...
# 80327 2013-09-09  21:15:00   nashville    tn      us     light
# 80328 2013-09-09  22:00:00       boise    id      us    circle
# 80329 2013-09-09  22:00:00        napa    ca      us     other
# 80330 2013-09-09  22:20:00      vienna    va      us    circle
# 80331 2013-09-09  23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted   latitude  \
# 0                   2700           45 minutes  2004-04-27  29.883056
# ...

# %%
df1.rename(columns={"duration":"duration (mins)"},inplace=True)

# %%
df1
# Out:
#             date      time        city state country     shape  \
# 0     1949-10-10  20:30:00  san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00        edna    tx      us    circle
# 4     1960-10-10  20:00:00     kaneohe    hi      us     light
# 5     1961-10-10  19:00:00     bristol    tn      us    sphere
# 7     1965-10-10  23:45:00     norwalk    ct      us      disk
# ...          ...       ...         ...   ...     ...       ...
# 80327 2013-09-09  21:15:00   nashville    tn      us     light
# 80328 2013-09-09  22:00:00       boise    id      us    circle
# 80329 2013-09-09  22:00:00        napa    ca      us     other
# 80330 2013-09-09  22:20:00      vienna    va      us    circle
# 80331 2013-09-09  23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted   latitude  \
# 0                   2700           45 minutes  2004-04-27  29.883056
# ...

# %%
df1.drop(columns=["duration (hours/min)"],inplace=True)

# %%
df1
# Out:
#             date      time        city state country     shape  \
# 0     1949-10-10  20:30:00  san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00        edna    tx      us    circle
# 4     1960-10-10  20:00:00     kaneohe    hi      us     light
# 5     1961-10-10  19:00:00     bristol    tn      us    sphere
# 7     1965-10-10  23:45:00     norwalk    ct      us      disk
# ...          ...       ...         ...   ...     ...       ...
# 80327 2013-09-09  21:15:00   nashville    tn      us     light
# 80328 2013-09-09  22:00:00       boise    id      us    circle
# 80329 2013-09-09  22:00:00        napa    ca      us     other
# 80330 2013-09-09  22:20:00      vienna    va      us    circle
# 80331 2013-09-09  23:00:00      edmond    ok      us     cigar
#
#       duration (seconds) date posted   latitude  longitude   duration (mins)
# 0                   2700  2004-04-27  29.883056  -97.941111             45.0
# ...

# %%
df1.dropna(how="any",inplace=True)

# %%
df1["duration (mins)"].convert_dtypes(convert_integer = True)
# Out:
# C:\Users\manis\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\manis\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# 0        45.0
# 3         5.0
# 4        20.0
# 5         3.0
# 7         3.0
#          ...
# 63570    20.0
# 63571    10.0
# 63572    20.0
# 63573     5.0
# 63574    17.0
# Name: duration (mins), Length: 52558, dtype: Float64

# %%
filtered_df1 = df1[df1["duration (mins)"] < 60]
filtered_df1
# Out:
#             date      time            city state country     shape  \
# 0     1949-10-10  20:30:00      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00            edna    tx      us    circle
# 4     1960-10-10  20:00:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45:00         norwalk    ct      us      disk
# ...          ...       ...             ...   ...     ...       ...
# 63570 2009-07-07  21:30:00          london    ky      us    circle
# 63571 2009-07-07  21:30:00       milwaukee    wi      us     other
# 63572 2009-07-07  21:45:00       fallsburg    ky      us  triangle
# 63573 2009-07-07  22:06:00  goodlettsville    tn      us     light
# 63574 2009-07-07  22:40:00     north ogden    ut      us     light
#
#       duration (seconds) date posted   latitude  longitude   duration (mins)
# 0                   2700  2004-04-27  29.883056  -97.941111             45.0
# ...

# %%
filtered_df1.drop(columns="date posted",inplace=True)
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_52204\3735388441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df1.drop(columns="date posted",inplace=True)

# %%
filtered_df1
# Out:
#             date      time            city state country     shape  \
# 0     1949-10-10  20:30:00      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00            edna    tx      us    circle
# 4     1960-10-10  20:00:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45:00         norwalk    ct      us      disk
# ...          ...       ...             ...   ...     ...       ...
# 63570 2009-07-07  21:30:00          london    ky      us    circle
# 63571 2009-07-07  21:30:00       milwaukee    wi      us     other
# 63572 2009-07-07  21:45:00       fallsburg    ky      us  triangle
# 63573 2009-07-07  22:06:00  goodlettsville    tn      us     light
# 63574 2009-07-07  22:40:00     north ogden    ut      us     light
#
#       duration (seconds)   latitude  longitude   duration (mins)
# 0                   2700  29.883056  -97.941111             45.0
# ...

# %%
df1 = filtered_df1

# %%
df1
# Out:
#             date      time            city state country     shape  \
# 0     1949-10-10  20:30:00      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00            edna    tx      us    circle
# 4     1960-10-10  20:00:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45:00         norwalk    ct      us      disk
# ...          ...       ...             ...   ...     ...       ...
# 63570 2009-07-07  21:30:00          london    ky      us    circle
# 63571 2009-07-07  21:30:00       milwaukee    wi      us     other
# 63572 2009-07-07  21:45:00       fallsburg    ky      us  triangle
# 63573 2009-07-07  22:06:00  goodlettsville    tn      us     light
# 63574 2009-07-07  22:40:00     north ogden    ut      us     light
#
#       duration (seconds)   latitude  longitude   duration (mins)
# 0                   2700  29.883056  -97.941111             45.0
# ...

# %%
df1.columns
# Out:
# Index(['date', 'time', 'city', 'state', 'country', 'shape',
#        'duration (seconds)', 'latitude', 'longitude ', 'duration (mins)'],
#       dtype='object')

# %%
df1 = df1.reindex(columns=['date', 'time', 'city', 'state', 'country', 'shape',
       'duration (seconds)', 'duration (mins)', 'latitude', 'longitude '])

# %%
df1
# Out:
#             date      time            city state country     shape  \
# 0     1949-10-10  20:30:00      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00            edna    tx      us    circle
# 4     1960-10-10  20:00:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45:00         norwalk    ct      us      disk
# ...          ...       ...             ...   ...     ...       ...
# 63570 2009-07-07  21:30:00          london    ky      us    circle
# 63571 2009-07-07  21:30:00       milwaukee    wi      us     other
# 63572 2009-07-07  21:45:00       fallsburg    ky      us  triangle
# 63573 2009-07-07  22:06:00  goodlettsville    tn      us     light
# 63574 2009-07-07  22:40:00     north ogden    ut      us     light
#
#       duration (seconds)  duration (mins)   latitude  longitude
# 0                   2700             45.0  29.883056  -97.941111
# ...

# %%
df1 = df1[df1["country"] == "us"]

# %%
df1
# Out:
#             date      time            city state country     shape  \
# 0     1949-10-10  20:30:00      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00:00            edna    tx      us    circle
# 4     1960-10-10  20:00:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45:00         norwalk    ct      us      disk
# ...          ...       ...             ...   ...     ...       ...
# 63570 2009-07-07  21:30:00          london    ky      us    circle
# 63571 2009-07-07  21:30:00       milwaukee    wi      us     other
# 63572 2009-07-07  21:45:00       fallsburg    ky      us  triangle
# 63573 2009-07-07  22:06:00  goodlettsville    tn      us     light
# 63574 2009-07-07  22:40:00     north ogden    ut      us     light
#
#       duration (seconds)  duration (mins)   latitude  longitude
# 0                   2700             45.0  29.883056  -97.941111
# ...

# %%
df1.to_csv("ufo_updated.csv")
